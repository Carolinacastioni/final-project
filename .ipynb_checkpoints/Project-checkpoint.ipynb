# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
im = Image.open("faces/30601258@N03/coarse_tilt_aligned_face.1.10399646885_67c7d20df9_o.jpg")
imarr = np.array(im)

# %%
imarr.shape
# Out:
# (600, 764, 3)

# %%
# %matplotlib inline

plt.imshow(imarr)

# %%
user_id	original_image	face_id	age	gender	x	y	dx	dy	tilt_ang	fiducial_yaw_angle	fiducial_score
30601258@N03	10399646885_67c7d20df9_o.jpg	1	(25, 23)	f	0	414	1086	1383	-115	30	17
# Out:
#   File "<ipython-input-23-2ce54cdad0d3>", line 1
#     user_id	original_image	face_id	age	gender	x	y	dx	dy	tilt_ang	fiducial_yaw_angle	fiducial_score
#            	             ^
# SyntaxError: invalid syntax
